# %%
# Import the dependencies.
import pandas as pd
import numpy as np

# %%
# Create a set of random latitude and longitude combina
lats = np.random.uniform(-90.000, 90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)
#lat_lngs = zip(lats, lngs)
#lat_lngs

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 765

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.

# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6ee06efa0b5c726075200f6e6412ff98

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_weather_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass
    
# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | puerto baquerizo moreno
# Processing Record 2 of Set 1 | carnarvon
# Processing Record 3 of Set 1 | rikitea
# Processing Record 4 of Set 1 | trairi
# Processing Record 5 of Set 1 | the valley
# Processing Record 6 of Set 1 | georgetown
# Processing Record 7 of Set 1 | nguiu
# City not found. Skipping...
# Processing Record 8 of Set 1 | hermanus
# Processing Record 9 of Set 1 | aykhal
# Processing Record 10 of Set 1 | yumen
# Processing Record 11 of Set 1 | upernavik
# Processing Record 12 of Set 1 | bluff
# Processing Record 13 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 14 of Set 1 | sobolevo
# Processing Record 15 of Set 1 | evensk
# Processing Record 16 of Set 1 | bethel
# Processing Record 17 of Set 1 | bethanien
# Processing Record 18 of Set 1 | hilo
# Processing Record 19 of Set 1 | vaini
# Processing Record 20 of Set 1 | albany
# Processing Record 21 of Set 1 | saint-philippe
# Processing Record 22 of Set 1 | vila velha
# Processing Record 23 of Set 1 | lebu
# Processing Record 24 of Set 1 | nanortalik
# Processing Record 25 of Set 1 | dandong
# Processing Record 26 of Set 1 | soto la marina
# Processing Record 27 of Set 1 | punta arenas
# Processing Record 28 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 29 of Set 1 | pangnirtung
# Processing Record 30 of Set 1 | gunzenhausen
# Processing Record 31 of Set 1 | belmonte
# Processing Record 32 of Set 1 | mataura
# Processing Record 33 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 34 of Set 1 | yulara
# Processing Record 35 of Set 1 | qaanaaq
# Processing Record 36 of Set 1 | karamea
# City not found. Skipping...
# Processing Record 37 of Set 1 | hualmay
# Processing Record 38 of Set 1 | mantua
# Processing Record 39 of Set 1 | kaitangata
# Processing Record 40 of Set 1 | waipawa
# Processing Record 41 of Set 1 | mogadishu
# Processing Record 42 of Set 1 | ushuaia
# Processing Record 43 of Set 1 | kyaikkami
# Processing Record 44 of Set 1 | souillac
# Processing Record 45 of Set 1 | thompson
# Processing Record 46 of Set 1 | clyde river
# Processing Record 47 of Set 1 | vardo
# Processing Record 48 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 49 of Set 1 | longyearbyen
# Processing Record 50 of Set 1 | aqtobe
# Processing Record 1 of Set 2 | cabedelo
# Processing Record 2 of Set 2 | hobart
# Processing Record 3 of Set 2 | cidreira
# Processing Record 4 of Set 2 | ust-kuyga
# Processing Record 5 of Set 2 | stege
# Processing Record 6 of Set 2 | carutapera
# Processing Record 7 of Set 2 | arraial do cabo
# Processing Record 8 of Set 2 | buin
# Processing Record 9 of Set 2 | dutse
# Processing Record 10 of Set 2 | cape town
# Processing Record 11 of Set 2 | khuzhir
# Processing Record 12 of Set 2 | mendahara
# City not found. Skipping...
# Processing Record 13 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 14 of Set 2 | faanui
# Processing Record 15 of Set 2 | khatanga
# Processing Record 16 of Set 2 | richards bay
# Processing Record 17 of Set 2 | cache creek
# Processing Record 18 of Set 2 | tongling
# Processing Record 19 of Set 2 | vestmannaeyjar
# Processing Record 20 of Set 2 | lubao
# Processing Record 21 of Set 2 | benghazi
# Processing Record 22 of Set 2 | constitucion
# Processing Record 23 of Set 2 | yara
# Processing Record 24 of Set 2 | bambous virieux
# Processing Record 25 of Set 2 | mahebourg
# Processing Record 26 of Set 2 | svetlyy
# Processing Record 27 of Set 2 | kongwa
# Processing Record 28 of Set 2 | avarua
# Processing Record 29 of Set 2 | port alfred
# Processing Record 30 of Set 2 | broken hill
# Processing Record 31 of Set 2 | kokoda
# Processing Record 32 of Set 2 | san patricio
# Processing Record 33 of Set 2 | sorvag
# City not found. Skipping...
# Processing Record 34 of Set 2 | sao miguel do araguaia
# Processing Record 35 of Set 2 | grand gaube
# Processing Record 36 of Set 2 | zhigansk
# Processing Record 37 of Set 2 | namibe
# Processing Record 38 of Set 2 | ahipara
# Processing Record 39 of Set 2 | puerto ayora
# Processing Record 40 of Set 2 | buala
# Processing Record 41 of Set 2 | asau
# Processing Record 42 of Set 2 | hasaki
# Processing Record 43 of Set 2 | mangrol
# Processing Record 44 of Set 2 | iqaluit
# Processing Record 45 of Set 2 | brae
# Processing Record 46 of Set 2 | dargaville
# Processing Record 47 of Set 2 | hamilton
# Processing Record 48 of Set 2 | busselton
# Processing Record 49 of Set 2 | kapaa
# Processing Record 50 of Set 2 | mount isa
# Processing Record 1 of Set 3 | esparta
# Processing Record 2 of Set 3 | antofagasta
# Processing Record 3 of Set 3 | new norfolk
# Processing Record 4 of Set 3 | bloomfield
# Processing Record 5 of Set 3 | stornoway
# Processing Record 6 of Set 3 | west wendover
# Processing Record 7 of Set 3 | margate
# Processing Record 8 of Set 3 | porto san giorgio
# Processing Record 9 of Set 3 | portsmouth
# Processing Record 10 of Set 3 | norman wells
# Processing Record 11 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 12 of Set 3 | guerrero negro
# Processing Record 13 of Set 3 | lindon
# Processing Record 14 of Set 3 | lorengau
# Processing Record 15 of Set 3 | chuy
# Processing Record 16 of Set 3 | ribeira grande
# Processing Record 17 of Set 3 | bredasdorp
# Processing Record 18 of Set 3 | bengkulu
# Processing Record 19 of Set 3 | rio gallegos
# Processing Record 20 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 21 of Set 3 | morrope
# Processing Record 22 of Set 3 | mayumba
# Processing Record 23 of Set 3 | cagayan de tawi-tawi
# City not found. Skipping...
# Processing Record 24 of Set 3 | tawkar
# City not found. Skipping...
# Processing Record 25 of Set 3 | mason city
# Processing Record 26 of Set 3 | jamestown
# Processing Record 27 of Set 3 | mirina
# City not found. Skipping...
# Processing Record 28 of Set 3 | talcahuano
# Processing Record 29 of Set 3 | rosarito
# Processing Record 30 of Set 3 | rio grande
# Processing Record 31 of Set 3 | castro
# Processing Record 32 of Set 3 | tasiilaq
# Processing Record 33 of Set 3 | la ronge
# Processing Record 34 of Set 3 | chapais
# Processing Record 35 of Set 3 | nome
# Processing Record 36 of Set 3 | saint-alexandre
# Processing Record 37 of Set 3 | ostrovnoy
# Processing Record 38 of Set 3 | tuktoyaktuk
# Processing Record 39 of Set 3 | alice springs
# Processing Record 40 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 41 of Set 3 | lasa
# Processing Record 42 of Set 3 | les cayes
# Processing Record 43 of Set 3 | katsuura
# Processing Record 44 of Set 3 | mariani
# Processing Record 45 of Set 3 | moranbah
# Processing Record 46 of Set 3 | korostyshiv
# Processing Record 47 of Set 3 | naples
# Processing Record 48 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 49 of Set 3 | palmer
# Processing Record 50 of Set 3 | port augusta
# Processing Record 1 of Set 4 | barrow
# Processing Record 2 of Set 4 | jibuti
# Processing Record 3 of Set 4 | portel
# Processing Record 4 of Set 4 | dikson
# Processing Record 5 of Set 4 | puerto del rosario
# Processing Record 6 of Set 4 | samarai
# Processing Record 7 of Set 4 | ribas do rio pardo
# Processing Record 8 of Set 4 | port lincoln
# Processing Record 9 of Set 4 | faya
# Processing Record 10 of Set 4 | kaspiyskiy
# Processing Record 11 of Set 4 | kununurra
# Processing Record 12 of Set 4 | mana
# Processing Record 13 of Set 4 | saint anthony
# Processing Record 14 of Set 4 | yeppoon
# Processing Record 15 of Set 4 | provideniya
# Processing Record 16 of Set 4 | port elizabeth
# Processing Record 17 of Set 4 | panixtlahuaca
# City not found. Skipping...
# Processing Record 18 of Set 4 | tuyen quang
# Processing Record 19 of Set 4 | hede
# Processing Record 20 of Set 4 | abay
# Processing Record 21 of Set 4 | westport
# Processing Record 22 of Set 4 | tottori
# Processing Record 23 of Set 4 | east london
# Processing Record 24 of Set 4 | kahului
# Processing Record 25 of Set 4 | cockburn town
# Processing Record 26 of Set 4 | kasane
# Processing Record 27 of Set 4 | alofi
# Processing Record 28 of Set 4 | springfield
# Processing Record 29 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 30 of Set 4 | piacabucu
# Processing Record 31 of Set 4 | qasigiannguit
# Processing Record 32 of Set 4 | jalu
# Processing Record 33 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 34 of Set 4 | northam
# Processing Record 35 of Set 4 | malaya serdoba
# Processing Record 36 of Set 4 | bonavista
# Processing Record 37 of Set 4 | east hemet
# Processing Record 38 of Set 4 | jabiru
# City not found. Skipping...
# Processing Record 39 of Set 4 | anadyr
# Processing Record 40 of Set 4 | atuona
# Processing Record 41 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 42 of Set 4 | sur
# Processing Record 43 of Set 4 | lhokseumawe
# Processing Record 44 of Set 4 | alto longa
# Processing Record 45 of Set 4 | primorka
# Processing Record 46 of Set 4 | mocuba
# Processing Record 47 of Set 4 | zlatoustovsk
# City not found. Skipping...
# Processing Record 48 of Set 4 | kabo
# Processing Record 49 of Set 4 | ancud
# Processing Record 50 of Set 4 | kavieng
# Processing Record 1 of Set 5 | san pedro
# Processing Record 2 of Set 5 | mar del plata
# Processing Record 3 of Set 5 | kamenka
# Processing Record 4 of Set 5 | saskylakh
# Processing Record 5 of Set 5 | yellowknife
# Processing Record 6 of Set 5 | gold coast
# Processing Record 7 of Set 5 | vostok
# Processing Record 8 of Set 5 | paime
# Processing Record 9 of Set 5 | tolaga bay
# Processing Record 10 of Set 5 | umea
# Processing Record 11 of Set 5 | sao joao da barra
# Processing Record 12 of Set 5 | dingle
# Processing Record 13 of Set 5 | aswan
# Processing Record 14 of Set 5 | toftir
# City not found. Skipping...
# Processing Record 15 of Set 5 | semey
# Processing Record 16 of Set 5 | avera
# Processing Record 17 of Set 5 | pevek
# Processing Record 18 of Set 5 | srednekolymsk
# Processing Record 19 of Set 5 | hami
# Processing Record 20 of Set 5 | verkhnevilyuysk
# Processing Record 21 of Set 5 | codrington
# Processing Record 22 of Set 5 | porto novo
# Processing Record 23 of Set 5 | port shepstone
# Processing Record 24 of Set 5 | hithadhoo
# Processing Record 25 of Set 5 | arlit
# Processing Record 26 of Set 5 | lavrentiya
# Processing Record 27 of Set 5 | mehamn
# Processing Record 28 of Set 5 | cherskiy
# Processing Record 29 of Set 5 | boras
# Processing Record 30 of Set 5 | fairbanks
# Processing Record 31 of Set 5 | narsaq
# Processing Record 32 of Set 5 | salalah
# Processing Record 33 of Set 5 | victoria
# Processing Record 34 of Set 5 | prieska
# Processing Record 35 of Set 5 | pionki
# Processing Record 36 of Set 5 | mahajanga
# Processing Record 37 of Set 5 | lodja
# Processing Record 38 of Set 5 | cayenne
# Processing Record 39 of Set 5 | rawson
# Processing Record 40 of Set 5 | college
# Processing Record 41 of Set 5 | sabha
# Processing Record 42 of Set 5 | zhanaozen
# Processing Record 43 of Set 5 | heide
# Processing Record 44 of Set 5 | mackay
# Processing Record 45 of Set 5 | saint-pierre
# Processing Record 46 of Set 5 | taraz
# Processing Record 47 of Set 5 | kilindoni
# Processing Record 48 of Set 5 | yenagoa
# Processing Record 49 of Set 5 | bilibino
# Processing Record 50 of Set 5 | kruisfontein
# Processing Record 1 of Set 6 | lompoc
# Processing Record 2 of Set 6 | barao de melgaco
# Processing Record 3 of Set 6 | mayo
# Processing Record 4 of Set 6 | palm beach
# Processing Record 5 of Set 6 | grindavik
# Processing Record 6 of Set 6 | saldanha
# Processing Record 7 of Set 6 | aklavik
# Processing Record 8 of Set 6 | una
# Processing Record 9 of Set 6 | zaysan
# Processing Record 10 of Set 6 | ruatoria
# City not found. Skipping...
# Processing Record 11 of Set 6 | mount gambier
# Processing Record 12 of Set 6 | airai
# Processing Record 13 of Set 6 | marcona
# City not found. Skipping...
# Processing Record 14 of Set 6 | mbanza-ngungu
# Processing Record 15 of Set 6 | kodiak
# Processing Record 16 of Set 6 | san policarpo
# Processing Record 17 of Set 6 | havre-saint-pierre
# Processing Record 18 of Set 6 | kochevo
# Processing Record 19 of Set 6 | winkler
# Processing Record 20 of Set 6 | klaksvik
# Processing Record 21 of Set 6 | butaritari
# Processing Record 22 of Set 6 | przhevalskoye
# Processing Record 23 of Set 6 | bardsir
# Processing Record 24 of Set 6 | naze
# Processing Record 25 of Set 6 | nikolskoye
# Processing Record 26 of Set 6 | lemesos
# City not found. Skipping...
# Processing Record 27 of Set 6 | quatre cocos
# Processing Record 28 of Set 6 | teguldet
# Processing Record 29 of Set 6 | chokurdakh
# Processing Record 30 of Set 6 | basco
# Processing Record 31 of Set 6 | isangel
# Processing Record 32 of Set 6 | warman
# Processing Record 33 of Set 6 | agsu
# City not found. Skipping...
# Processing Record 34 of Set 6 | zonguldak
# Processing Record 35 of Set 6 | iquitos
# Processing Record 36 of Set 6 | boljevac
# Processing Record 37 of Set 6 | uruacu
# Processing Record 38 of Set 6 | khandyga
# Processing Record 39 of Set 6 | buraydah
# Processing Record 40 of Set 6 | xaxim
# Processing Record 41 of Set 6 | shimoda
# Processing Record 42 of Set 6 | tshane
# Processing Record 43 of Set 6 | pilar
# Processing Record 44 of Set 6 | half moon bay
# Processing Record 45 of Set 6 | atasu
# Processing Record 46 of Set 6 | savelugu
# Processing Record 47 of Set 6 | szydlowiec
# Processing Record 48 of Set 6 | medea
# Processing Record 49 of Set 6 | japura
# Processing Record 50 of Set 6 | peniche
# Processing Record 1 of Set 7 | paamiut
# Processing Record 2 of Set 7 | oyama
# Processing Record 3 of Set 7 | bartica
# Processing Record 4 of Set 7 | gotsu
# Processing Record 5 of Set 7 | goma
# Processing Record 6 of Set 7 | teguise
# Processing Record 7 of Set 7 | karaul
# City not found. Skipping...
# Processing Record 8 of Set 7 | verkh-chebula
# Processing Record 9 of Set 7 | high level
# Processing Record 10 of Set 7 | puerto madryn
# Processing Record 11 of Set 7 | laguna
# Processing Record 12 of Set 7 | saint george
# Processing Record 13 of Set 7 | afyonkarahisar
# Processing Record 14 of Set 7 | nestorion
# City not found. Skipping...
# Processing Record 15 of Set 7 | hirara
# Processing Record 16 of Set 7 | challapata
# Processing Record 17 of Set 7 | sitka
# Processing Record 18 of Set 7 | grenfell
# Processing Record 19 of Set 7 | okato
# Processing Record 20 of Set 7 | mmabatho
# Processing Record 21 of Set 7 | talara
# Processing Record 22 of Set 7 | umm ruwabah
# City not found. Skipping...
# Processing Record 23 of Set 7 | donskoye
# Processing Record 24 of Set 7 | sangar
# Processing Record 25 of Set 7 | taoudenni
# Processing Record 26 of Set 7 | yerbogachen
# Processing Record 27 of Set 7 | neustadt
# Processing Record 28 of Set 7 | nishihara
# Processing Record 29 of Set 7 | sao bento do sul
# Processing Record 30 of Set 7 | petropavlovsk-kamchatskiy
# Processing Record 31 of Set 7 | adrar
# Processing Record 32 of Set 7 | sorland
# Processing Record 33 of Set 7 | khandbari
# Processing Record 34 of Set 7 | ketchikan
# Processing Record 35 of Set 7 | san jose
# Processing Record 36 of Set 7 | kalmunai
# Processing Record 37 of Set 7 | chester
# Processing Record 38 of Set 7 | anaconda
# Processing Record 39 of Set 7 | faranah
# Processing Record 40 of Set 7 | humaita
# Processing Record 41 of Set 7 | hobyo
# Processing Record 42 of Set 7 | madang
# Processing Record 43 of Set 7 | manavalakurichi
# Processing Record 44 of Set 7 | yar-sale
# Processing Record 45 of Set 7 | yaan
# Processing Record 46 of Set 7 | pacific grove
# Processing Record 47 of Set 7 | butembo
# Processing Record 48 of Set 7 | gumdag
# Processing Record 49 of Set 7 | birao
# Processing Record 50 of Set 7 | marystown
# Processing Record 1 of Set 8 | smolyaninovo
# Processing Record 2 of Set 8 | sept-iles
# Processing Record 3 of Set 8 | port-cartier
# Processing Record 4 of Set 8 | astana
# Processing Record 5 of Set 8 | tabuk
# Processing Record 6 of Set 8 | eldikan
# City not found. Skipping...
# Processing Record 7 of Set 8 | mailani
# Processing Record 8 of Set 8 | asfi
# Processing Record 9 of Set 8 | abha
# Processing Record 10 of Set 8 | lagoa
# Processing Record 11 of Set 8 | desur
# Processing Record 12 of Set 8 | goderich
# Processing Record 13 of Set 8 | loukhi
# Processing Record 14 of Set 8 | kansk
# Processing Record 15 of Set 8 | bairnsdale
# Processing Record 16 of Set 8 | praia
# Processing Record 17 of Set 8 | viligili
# City not found. Skipping...
# Processing Record 18 of Set 8 | fort saint john
# City not found. Skipping...
# Processing Record 19 of Set 8 | kula
# Processing Record 20 of Set 8 | berezanka
# Processing Record 21 of Set 8 | tucupita
# Processing Record 22 of Set 8 | belaya gora
# Processing Record 23 of Set 8 | marsh harbour
# Processing Record 24 of Set 8 | havelock
# Processing Record 25 of Set 8 | xichang
# Processing Record 26 of Set 8 | catamarca
# Processing Record 27 of Set 8 | fort nelson
# Processing Record 28 of Set 8 | leme
# Processing Record 29 of Set 8 | polunochnoye
# Processing Record 30 of Set 8 | kamaishi
# Processing Record 31 of Set 8 | aksu
# Processing Record 32 of Set 8 | torbay
# Processing Record 33 of Set 8 | fortuna
# Processing Record 34 of Set 8 | revelstoke
# Processing Record 35 of Set 8 | baculin
# Processing Record 36 of Set 8 | salym
# Processing Record 37 of Set 8 | kefamenanu
# Processing Record 38 of Set 8 | washington
# Processing Record 39 of Set 8 | mao
# Processing Record 40 of Set 8 | shitanjing
# Processing Record 41 of Set 8 | flin flon
# Processing Record 42 of Set 8 | olafsvik
# Processing Record 43 of Set 8 | kuito
# Processing Record 44 of Set 8 | verkh-usugli
# Processing Record 45 of Set 8 | nachingwea
# Processing Record 46 of Set 8 | hun
# Processing Record 47 of Set 8 | nguru
# Processing Record 48 of Set 8 | kokopo
# Processing Record 49 of Set 8 | ayorou
# Processing Record 50 of Set 8 | saleaula
# City not found. Skipping...
# Processing Record 1 of Set 9 | sao filipe
# Processing Record 2 of Set 9 | aflu
# City not found. Skipping...
# Processing Record 3 of Set 9 | nyurba
# Processing Record 4 of Set 9 | rayevskiy
# Processing Record 5 of Set 9 | los llanos de aridane
# Processing Record 6 of Set 9 | banff
# Processing Record 7 of Set 9 | huilong
# Processing Record 8 of Set 9 | comodoro rivadavia
# Processing Record 9 of Set 9 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 10 of Set 9 | hambantota
# Processing Record 11 of Set 9 | salihorsk
# Processing Record 12 of Set 9 | yakeshi
# Processing Record 13 of Set 9 | upington
# Processing Record 14 of Set 9 | esperance
# Processing Record 15 of Set 9 | qui nhon
# Processing Record 16 of Set 9 | taburi
# City not found. Skipping...
# Processing Record 17 of Set 9 | katherine
# Processing Record 18 of Set 9 | seoul
# Processing Record 19 of Set 9 | cadillac
# Processing Record 20 of Set 9 | tecoanapa
# Processing Record 21 of Set 9 | palana
# Processing Record 22 of Set 9 | cabo san lucas
# Processing Record 23 of Set 9 | kerewan
# Processing Record 24 of Set 9 | pasighat
# Processing Record 25 of Set 9 | mezen
# Processing Record 26 of Set 9 | klyuchi
# Processing Record 27 of Set 9 | buluang
# Processing Record 28 of Set 9 | changji
# Processing Record 29 of Set 9 | chanika
# Processing Record 30 of Set 9 | wahran
# City not found. Skipping...
# Processing Record 31 of Set 9 | leh
# Processing Record 32 of Set 9 | kavaratti
# Processing Record 33 of Set 9 | shupiyan
# Processing Record 34 of Set 9 | nabire
# Processing Record 35 of Set 9 | lata
# Processing Record 36 of Set 9 | byron bay
# Processing Record 37 of Set 9 | hushitai
# Processing Record 38 of Set 9 | bandarbeyla
# Processing Record 39 of Set 9 | riyadh
# Processing Record 40 of Set 9 | boissevain
# Processing Record 41 of Set 9 | manali
# Processing Record 42 of Set 9 | coquimbo
# Processing Record 43 of Set 9 | barcelos
# Processing Record 44 of Set 9 | nanchital
# Processing Record 45 of Set 9 | pedernales
# Processing Record 46 of Set 9 | sambava
# Processing Record 47 of Set 9 | mobaye
# Processing Record 48 of Set 9 | saint-joseph
# Processing Record 49 of Set 9 | douentza
# Processing Record 50 of Set 9 | tura
# Processing Record 1 of Set 10 | tamandare
# Processing Record 2 of Set 10 | leningradskiy
# Processing Record 3 of Set 10 | cap malheureux
# Processing Record 4 of Set 10 | dryden
# Processing Record 5 of Set 10 | cabul-an
# Processing Record 6 of Set 10 | williams lake
# Processing Record 7 of Set 10 | comarapa
# Processing Record 8 of Set 10 | praia da vitoria
# Processing Record 9 of Set 10 | husavik
# Processing Record 10 of Set 10 | udon thani
# Processing Record 11 of Set 10 | nouadhibou
# Processing Record 12 of Set 10 | korla
# Processing Record 13 of Set 10 | roebourne
# Processing Record 14 of Set 10 | deputatskiy
# Processing Record 15 of Set 10 | turukhansk
# Processing Record 16 of Set 10 | ardatov
# Processing Record 17 of Set 10 | muana
# Processing Record 18 of Set 10 | nouakchott
# Processing Record 19 of Set 10 | mackenzie
# Processing Record 20 of Set 10 | barstow
# Processing Record 21 of Set 10 | kutum
# Processing Record 22 of Set 10 | vinh
# Processing Record 23 of Set 10 | samusu
# City not found. Skipping...
# Processing Record 24 of Set 10 | san pedro de lloc
# Processing Record 25 of Set 10 | vega de alatorre
# Processing Record 26 of Set 10 | namatanai
# Processing Record 27 of Set 10 | horsham
# Processing Record 28 of Set 10 | blonduos
# City not found. Skipping...
# Processing Record 29 of Set 10 | vitimskiy
# City not found. Skipping...
# Processing Record 30 of Set 10 | hire
# City not found. Skipping...
# Processing Record 31 of Set 10 | trelew
# Processing Record 32 of Set 10 | nelson bay
# Processing Record 33 of Set 10 | tilichiki
# Processing Record 34 of Set 10 | bella vista
# Processing Record 35 of Set 10 | lake city
# Processing Record 36 of Set 10 | nador
# Processing Record 37 of Set 10 | severo-kurilsk
# Processing Record 38 of Set 10 | tshikapa
# Processing Record 39 of Set 10 | xining
# Processing Record 40 of Set 10 | waingapu
# Processing Record 41 of Set 10 | roald
# Processing Record 42 of Set 10 | tulagi
# Processing Record 43 of Set 10 | den helder
# Processing Record 44 of Set 10 | la tuque
# Processing Record 45 of Set 10 | glomfjord
# Processing Record 46 of Set 10 | tres arroyos
# Processing Record 47 of Set 10 | tumannyy
# City not found. Skipping...
# Processing Record 48 of Set 10 | palembang
# Processing Record 49 of Set 10 | port macquarie
# Processing Record 50 of Set 10 | oranjestad
# Processing Record 1 of Set 11 | necochea
# Processing Record 2 of Set 11 | si sa ket
# Processing Record 3 of Set 11 | hofn
# Processing Record 4 of Set 11 | copiapo
# Processing Record 5 of Set 11 | isla vista
# Processing Record 6 of Set 11 | svay rieng
# Processing Record 7 of Set 11 | talaya
# Processing Record 8 of Set 11 | gobindpur
# Processing Record 9 of Set 11 | suntar
# Processing Record 10 of Set 11 | dudinka
# Processing Record 11 of Set 11 | macaboboni
# City not found. Skipping...
# Processing Record 12 of Set 11 | kollam
# Processing Record 13 of Set 11 | bunia
# Processing Record 14 of Set 11 | bilma
# Processing Record 15 of Set 11 | utiroa
# City not found. Skipping...
# Processing Record 16 of Set 11 | sarangani
# Processing Record 17 of Set 11 | athabasca
# Processing Record 18 of Set 11 | nemuro
# Processing Record 19 of Set 11 | ilhabela
# Processing Record 20 of Set 11 | dobryanka
# Processing Record 21 of Set 11 | port hardy
# Processing Record 22 of Set 11 | tiksi
# Processing Record 23 of Set 11 | koryukivka
# Processing Record 24 of Set 11 | sydney
# Processing Record 25 of Set 11 | camacha
# Processing Record 26 of Set 11 | vuktyl
# Processing Record 27 of Set 11 | gigmoto
# Processing Record 28 of Set 11 | mapiripan
# Processing Record 29 of Set 11 | thunder bay
# Processing Record 30 of Set 11 | georgiyevka
# Processing Record 31 of Set 11 | pingliang
# Processing Record 32 of Set 11 | cam ranh
# Processing Record 33 of Set 11 | sokoni
# Processing Record 34 of Set 11 | southbridge
# Processing Record 35 of Set 11 | poronaysk
# Processing Record 36 of Set 11 | sao jose da coroa grande
# Processing Record 37 of Set 11 | qurayyat
# Processing Record 38 of Set 11 | tariba
# Processing Record 39 of Set 11 | bermeo
# Processing Record 40 of Set 11 | tiruvottiyur
# City not found. Skipping...
# Processing Record 41 of Set 11 | yarim
# Processing Record 42 of Set 11 | ngukurr
# City not found. Skipping...
# Processing Record 43 of Set 11 | kangaatsiaq
# Processing Record 44 of Set 11 | geraldton
# Processing Record 45 of Set 11 | macduff
# Processing Record 46 of Set 11 | svetlaya
# Processing Record 47 of Set 11 | gra liyia
# Processing Record 48 of Set 11 | wulanhaote
# City not found. Skipping...
# Processing Record 49 of Set 11 | redmond
# Processing Record 50 of Set 11 | watertown
# Processing Record 1 of Set 12 | naftah
# City not found. Skipping...
# Processing Record 2 of Set 12 | cochrane
# Processing Record 3 of Set 12 | moratuwa
# Processing Record 4 of Set 12 | jamame
# Processing Record 5 of Set 12 | council bluffs
# Processing Record 6 of Set 12 | nichinan
# Processing Record 7 of Set 12 | morgan city
# Processing Record 8 of Set 12 | jacareacanga
# Processing Record 9 of Set 12 | dhidhdhoo
# Processing Record 10 of Set 12 | herat
# Processing Record 11 of Set 12 | kuusamo
# Processing Record 12 of Set 12 | texarkana
# Processing Record 13 of Set 12 | beboto
# Processing Record 14 of Set 12 | nesbyen
# Processing Record 15 of Set 12 | dicabisagan
# Processing Record 16 of Set 12 | venice
# Processing Record 17 of Set 12 | ust-koksa
# Processing Record 18 of Set 12 | nuuk
# Processing Record 19 of Set 12 | biak
# Processing Record 20 of Set 12 | ondorhaan
# City not found. Skipping...
# Processing Record 21 of Set 12 | berlevag
# Processing Record 22 of Set 12 | bahir dar
# Processing Record 23 of Set 12 | arman
# Processing Record 24 of Set 12 | flinders
# Processing Record 25 of Set 12 | kidal
# Processing Record 26 of Set 12 | ragusa
# Processing Record 27 of Set 12 | labuhan
# Processing Record 28 of Set 12 | usinsk
# Processing Record 29 of Set 12 | grand forks
# Processing Record 30 of Set 12 | zambezi
# Processing Record 31 of Set 12 | santa rosa
# Processing Record 32 of Set 12 | luderitz
# Processing Record 33 of Set 12 | jinja
# Processing Record 34 of Set 12 | bardiyah
# Processing Record 35 of Set 12 | ternate
# Processing Record 36 of Set 12 | dunlop
# Processing Record 37 of Set 12 | presidencia roque saenz pena
# Processing Record 38 of Set 12 | andenes
# Processing Record 39 of Set 12 | pisco
# Processing Record 40 of Set 12 | umm lajj
# Processing Record 41 of Set 12 | hovd
# Processing Record 42 of Set 12 | yatou
# Processing Record 43 of Set 12 | krasnoselkup
# Processing Record 44 of Set 12 | zavitinsk
# Processing Record 45 of Set 12 | nizwa
# Processing Record 46 of Set 12 | salinopolis
# Processing Record 47 of Set 12 | rocklin
# Processing Record 48 of Set 12 | aripuana
# Processing Record 49 of Set 12 | baruun-urt
# Processing Record 50 of Set 12 | goundam
# Processing Record 1 of Set 13 | ust-tsilma
# Processing Record 2 of Set 13 | anchorage
# Processing Record 3 of Set 13 | manakara
# Processing Record 4 of Set 13 | safranbolu
# Processing Record 5 of Set 13 | aneho
# Processing Record 6 of Set 13 | tiznit
# Processing Record 7 of Set 13 | bowen
# Processing Record 8 of Set 13 | egvekinot
# Processing Record 9 of Set 13 | san cristobal
# Processing Record 10 of Set 13 | moose factory
# Processing Record 11 of Set 13 | preobrazhenskaya
# City not found. Skipping...
# Processing Record 12 of Set 13 | tarko-sale
# Processing Record 13 of Set 13 | minbu
# Processing Record 14 of Set 13 | abyek
# Processing Record 15 of Set 13 | kristiinankaupunki
# Processing Record 16 of Set 13 | baranain
# Processing Record 17 of Set 13 | wajima
# Processing Record 18 of Set 13 | wakkanai
# Processing Record 19 of Set 13 | san quintin
# Processing Record 20 of Set 13 | santa fe
# Processing Record 21 of Set 13 | ingham
# Processing Record 22 of Set 13 | koumra
# Processing Record 23 of Set 13 | pampa
# Processing Record 24 of Set 13 | tiassale
# Processing Record 25 of Set 13 | bubaque
# Processing Record 26 of Set 13 | jasper
# Processing Record 27 of Set 13 | quelimane
# Processing Record 28 of Set 13 | pallasovka
# Processing Record 29 of Set 13 | vallenar
# Processing Record 30 of Set 13 | vangaindrano
# Processing Record 31 of Set 13 | ca mau
# Processing Record 32 of Set 13 | pyshma
# Processing Record 33 of Set 13 | yining
# Processing Record 34 of Set 13 | guanay
# Processing Record 35 of Set 13 | gamba
# Processing Record 36 of Set 13 | kawalu
# Processing Record 37 of Set 13 | mrirt
# City not found. Skipping...
# Processing Record 38 of Set 13 | gat
# Processing Record 39 of Set 13 | pattani
# Processing Record 40 of Set 13 | sidi ali
# Processing Record 41 of Set 13 | beloha
# Processing Record 42 of Set 13 | vradiyivka
# Processing Record 43 of Set 13 | bathsheba
# Processing Record 44 of Set 13 | detva
# Processing Record 45 of Set 13 | abu zabad
# Processing Record 46 of Set 13 | kinanah
# City not found. Skipping...
# Processing Record 47 of Set 13 | falmouth
# Processing Record 48 of Set 13 | mount darwin
# Processing Record 49 of Set 13 | churapcha
# Processing Record 50 of Set 13 | chiredzi
# Processing Record 1 of Set 14 | gazanjyk
# Processing Record 2 of Set 14 | craigieburn
# Processing Record 3 of Set 14 | nahariyya
# Processing Record 4 of Set 14 | lithakia
# Processing Record 5 of Set 14 | winnemucca
# Processing Record 6 of Set 14 | rabo de peixe
# Processing Record 7 of Set 14 | karratha
# Processing Record 8 of Set 14 | toma
# Processing Record 9 of Set 14 | weyburn
# Processing Record 10 of Set 14 | vila franca do campo
# Processing Record 11 of Set 14 | brownfield
# Processing Record 12 of Set 14 | antalaha
# Processing Record 13 of Set 14 | iracoubo
# Processing Record 14 of Set 14 | bairiki
# Processing Record 15 of Set 14 | montrose
# Processing Record 16 of Set 14 | ballina
# Processing Record 17 of Set 14 | churhat
# Processing Record 18 of Set 14 | portland
# Processing Record 19 of Set 14 | san andres
# Processing Record 20 of Set 14 | barcelona
# Processing Record 21 of Set 14 | tostedt
# Processing Record 22 of Set 14 | chalons-en-champagne
# Processing Record 23 of Set 14 | parit buntar
# Processing Record 24 of Set 14 | ivybridge
# Processing Record 25 of Set 14 | gambela
# Processing Record 26 of Set 14 | bat khela
# Processing Record 27 of Set 14 | khambhat
# Processing Record 28 of Set 14 | ningan
# City not found. Skipping...
# Processing Record 29 of Set 14 | san ramon
# Processing Record 30 of Set 14 | tual
# Processing Record 31 of Set 14 | kattivakkam
# Processing Record 32 of Set 14 | terrace bay
# Processing Record 33 of Set 14 | mestia
# Processing Record 34 of Set 14 | kargil
# Processing Record 35 of Set 14 | pacasmayo
# Processing Record 36 of Set 14 | dutlwe
# Processing Record 37 of Set 14 | olen
# Processing Record 38 of Set 14 | mazagao
# Processing Record 39 of Set 14 | maceio
# Processing Record 40 of Set 14 | thurso
# Processing Record 41 of Set 14 | galway
# Processing Record 42 of Set 14 | davila
# Processing Record 43 of Set 14 | mulege
# Processing Record 44 of Set 14 | dzhusaly
# City not found. Skipping...
# Processing Record 45 of Set 14 | victor harbor
# Processing Record 46 of Set 14 | martaban
# Processing Record 47 of Set 14 | smirnykh
# Processing Record 48 of Set 14 | dunedin
# Processing Record 49 of Set 14 | raga
# Processing Record 50 of Set 14 | russellville
# Processing Record 1 of Set 15 | belyy yar
# Processing Record 2 of Set 15 | wernigerode
# Processing Record 3 of Set 15 | juegang
# Processing Record 4 of Set 15 | kissamos
# Processing Record 5 of Set 15 | ilulissat
# Processing Record 6 of Set 15 | idenao
# Processing Record 7 of Set 15 | gurgan
# City not found. Skipping...
# Processing Record 8 of Set 15 | gagnoa
# Processing Record 9 of Set 15 | bassila
# Processing Record 10 of Set 15 | singaraja
# Processing Record 11 of Set 15 | kitob
# Processing Record 12 of Set 15 | osa
# Processing Record 13 of Set 15 | chegdomyn
# Processing Record 14 of Set 15 | shache
# Processing Record 15 of Set 15 | artyk
# City not found. Skipping...
# Processing Record 16 of Set 15 | umtata
# Processing Record 17 of Set 15 | ruteng
# Processing Record 18 of Set 15 | hastings
# Processing Record 19 of Set 15 | wundanyi
# Processing Record 20 of Set 15 | dohrighat
# Processing Record 21 of Set 15 | dong xoai
# Processing Record 22 of Set 15 | dalvik
# Processing Record 23 of Set 15 | talnakh
# Processing Record 24 of Set 15 | wagar
# Processing Record 25 of Set 15 | fevik
# Processing Record 26 of Set 15 | rocha
# Processing Record 27 of Set 15 | iskenderun
# Processing Record 28 of Set 15 | poso
# Processing Record 29 of Set 15 | kozan
# Processing Record 30 of Set 15 | moshny
# Processing Record 31 of Set 15 | ponta do sol
# Processing Record 32 of Set 15 | port keats
# Processing Record 33 of Set 15 | garissa
# Processing Record 34 of Set 15 | walvis bay
# Processing Record 35 of Set 15 | kaspiysk
# Processing Record 36 of Set 15 | sitarganj
# Processing Record 37 of Set 15 | miri
# Processing Record 38 of Set 15 | ji-parana
# City not found. Skipping...
# Processing Record 39 of Set 15 | acqui terme
# Processing Record 40 of Set 15 | itarema
# Processing Record 41 of Set 15 | corsicana
# Processing Record 42 of Set 15 | jiddah
# City not found. Skipping...
# Processing Record 43 of Set 15 | matane
# Processing Record 44 of Set 15 | haines junction
# Processing Record 45 of Set 15 | broome
# Processing Record 46 of Set 15 | te anau
# Processing Record 47 of Set 15 | ryki
# Processing Record 48 of Set 15 | poum
# Processing Record 49 of Set 15 | sahuaripa
# Processing Record 50 of Set 15 | erenhot
# Processing Record 1 of Set 16 | diedorf
# Processing Record 2 of Set 16 | barbar
# City not found. Skipping...
# Processing Record 3 of Set 16 | znamenskoye
# Processing Record 4 of Set 16 | kalabo
# Processing Record 5 of Set 16 | eyemouth
# Processing Record 6 of Set 16 | saint-francois
# Processing Record 7 of Set 16 | karlshamn
# Processing Record 8 of Set 16 | andrelandia
# Processing Record 9 of Set 16 | palabuhanratu
# City not found. Skipping...
# Processing Record 10 of Set 16 | diofior
# Processing Record 11 of Set 16 | chala
# Processing Record 12 of Set 16 | porangatu
# Processing Record 13 of Set 16 | point fortin
# Processing Record 14 of Set 16 | ponta delgada
# Processing Record 15 of Set 16 | alexandria
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 704

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#                       City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Puerto Baquerizo Moreno  -0.9000  -89.6000     77.49        82          54
# 1                Carnarvon -24.8667  113.6333     93.20        38           0
# 2                  Rikitea -23.1203 -134.9692     78.28        75         100
# 3                   Trairi  -3.2778  -39.2689     75.96        92         100
# 4               The Valley  18.2170  -63.0578     77.00        69          20
# 5               Georgetown   5.4112  100.3354     89.60        70          20
# 6                 Hermanus -34.4187   19.2345     59.00        94          97
# 7                   Aykhal  66.0000  111.5000     -9.74        86         100
# 8                    Yumen  40.2833   97.2000     40.17        46         100
# 9                Upernavik  72.7868  -56.1549      7.14        70         100
#
#    Wind Speed Country Current Description
# 0        3.49      EC       broken clouds
# 1       16.11      AU           clear sky
# 2       15.66      PF          light rain
# 3        6.62      BR     overcast clouds
# 4       11.50      AI          few clouds
# 5        6.91      MY          few clouds
# 6        4.36      ZA     overcast clouds
# 7       13.87      RU     overcast clouds
# 8        4.52      CN     overcast clouds
# 9        4.59      GL     overcast clouds

# %%
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df
# Out:
#                         City Country      Lat       Lng  Max Temp  Humidity  \
# 0    Puerto Baquerizo Moreno      EC  -0.9000  -89.6000     77.49        82
# 1                  Carnarvon      AU -24.8667  113.6333     93.20        38
# 2                    Rikitea      PF -23.1203 -134.9692     78.28        75
# 3                     Trairi      BR  -3.2778  -39.2689     75.96        92
# 4                 The Valley      AI  18.2170  -63.0578     77.00        69
# ..                       ...     ...      ...       ...       ...       ...
# 699                    Chala      TZ  -7.5833   31.2667     55.85        97
# 700                Porangatu      BR -13.4408  -49.1486     72.41        72
# 701             Point Fortin      TT  10.1833  -61.6833     75.00        92
# 702            Ponta Delgada      PT  37.7333  -25.6667     57.20        82
# 703               Alexandria      EG  31.2156   29.9553     50.00        81
#
#      Cloudiness  Wind Speed Current Description
# 0            54        3.49       broken clouds
# 1             0       16.11           clear sky
# 2           100       15.66          light rain
# 3           100        6.62     overcast clouds
# 4            20       11.50          few clouds
# ..          ...         ...                 ...
# 699          90        4.54     overcast clouds
# 700          12        2.04          few clouds
# 701          37       13.62    scattered clouds
# 702          20        4.61          few clouds
# 703          40        4.61    scattered clouds
#
# [704 rows x 9 columns]

# %%
# Create the output file (CSV).

output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
