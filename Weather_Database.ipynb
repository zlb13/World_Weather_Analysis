# %%
# Import the dependencies.
import pandas as pd
import numpy as np

# %%
# Create a set of random latitude and longitude combina
lats = np.random.uniform(-90.000, 90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)
#lat_lngs = zip(lats, lngs)
#lat_lngs

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 767

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.

# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6ee06efa0b5c726075200f6e6412ff98

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_weather_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass
    
# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | albany
# Processing Record 2 of Set 1 | bluff
# Processing Record 3 of Set 1 | kuusamo
# Processing Record 4 of Set 1 | tasiilaq
# Processing Record 5 of Set 1 | bambous virieux
# Processing Record 6 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 7 of Set 1 | aklavik
# Processing Record 8 of Set 1 | airai
# Processing Record 9 of Set 1 | rawson
# Processing Record 10 of Set 1 | mahebourg
# Processing Record 11 of Set 1 | beira
# Processing Record 12 of Set 1 | saint-philippe
# Processing Record 13 of Set 1 | poum
# Processing Record 14 of Set 1 | port macquarie
# Processing Record 15 of Set 1 | busselton
# Processing Record 16 of Set 1 | punta arenas
# Processing Record 17 of Set 1 | yellowknife
# Processing Record 18 of Set 1 | hilo
# Processing Record 19 of Set 1 | georgetown
# Processing Record 20 of Set 1 | bowen
# Processing Record 21 of Set 1 | flinders
# Processing Record 22 of Set 1 | lata
# Processing Record 23 of Set 1 | cape town
# Processing Record 24 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 25 of Set 1 | longyearbyen
# Processing Record 26 of Set 1 | mityana
# Processing Record 27 of Set 1 | koundara
# Processing Record 28 of Set 1 | ushuaia
# Processing Record 29 of Set 1 | evensk
# Processing Record 30 of Set 1 | broome
# Processing Record 31 of Set 1 | sandy bay
# Processing Record 32 of Set 1 | jijiga
# Processing Record 33 of Set 1 | lavrentiya
# Processing Record 34 of Set 1 | provideniya
# Processing Record 35 of Set 1 | bredasdorp
# Processing Record 36 of Set 1 | geraldton
# Processing Record 37 of Set 1 | gull lake
# Processing Record 38 of Set 1 | hobart
# Processing Record 39 of Set 1 | rikitea
# Processing Record 40 of Set 1 | tessalit
# Processing Record 41 of Set 1 | kruisfontein
# Processing Record 42 of Set 1 | orlik
# Processing Record 43 of Set 1 | kuche
# City not found. Skipping...
# Processing Record 44 of Set 1 | butaritari
# Processing Record 45 of Set 1 | faanui
# Processing Record 46 of Set 1 | hay river
# Processing Record 47 of Set 1 | mailani
# Processing Record 48 of Set 1 | birao
# Processing Record 49 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 50 of Set 1 | dzhusaly
# City not found. Skipping...
# Processing Record 1 of Set 2 | baruun-urt
# Processing Record 2 of Set 2 | cherskiy
# Processing Record 3 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 4 of Set 2 | lebu
# Processing Record 5 of Set 2 | ixtapa
# Processing Record 6 of Set 2 | partizanskoye
# Processing Record 7 of Set 2 | asosa
# Processing Record 8 of Set 2 | ponta do sol
# Processing Record 9 of Set 2 | tabarqah
# City not found. Skipping...
# Processing Record 10 of Set 2 | qui nhon
# Processing Record 11 of Set 2 | gasa
# Processing Record 12 of Set 2 | eureka
# Processing Record 13 of Set 2 | barrow
# Processing Record 14 of Set 2 | raipur
# Processing Record 15 of Set 2 | inhambane
# Processing Record 16 of Set 2 | tuktoyaktuk
# Processing Record 17 of Set 2 | pevek
# Processing Record 18 of Set 2 | port augusta
# Processing Record 19 of Set 2 | sorland
# Processing Record 20 of Set 2 | patan
# Processing Record 21 of Set 2 | port alfred
# Processing Record 22 of Set 2 | thompson
# Processing Record 23 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 24 of Set 2 | praia da vitoria
# Processing Record 25 of Set 2 | tahta
# Processing Record 26 of Set 2 | pingliang
# Processing Record 27 of Set 2 | jamestown
# Processing Record 28 of Set 2 | new norfolk
# Processing Record 29 of Set 2 | nanortalik
# Processing Record 30 of Set 2 | katsuura
# Processing Record 31 of Set 2 | ayan
# Processing Record 32 of Set 2 | moron
# Processing Record 33 of Set 2 | vaini
# Processing Record 34 of Set 2 | port blair
# Processing Record 35 of Set 2 | egvekinot
# Processing Record 36 of Set 2 | hithadhoo
# Processing Record 37 of Set 2 | rudbar
# Processing Record 38 of Set 2 | paucartambo
# City not found. Skipping...
# Processing Record 39 of Set 2 | omutinskoye
# City not found. Skipping...
# Processing Record 40 of Set 2 | salalah
# Processing Record 41 of Set 2 | taylorville
# Processing Record 42 of Set 2 | dikson
# Processing Record 43 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 44 of Set 2 | turka
# Processing Record 45 of Set 2 | vila franca do campo
# Processing Record 46 of Set 2 | tuatapere
# Processing Record 47 of Set 2 | los llanos de aridane
# Processing Record 48 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 49 of Set 2 | abu dhabi
# Processing Record 50 of Set 2 | hermanus
# Processing Record 1 of Set 3 | norman wells
# Processing Record 2 of Set 3 | hamilton
# Processing Record 3 of Set 3 | luanda
# Processing Record 4 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 5 of Set 3 | aguilar de la frontera
# Processing Record 6 of Set 3 | san vicente
# Processing Record 7 of Set 3 | castro
# Processing Record 8 of Set 3 | qaanaaq
# Processing Record 9 of Set 3 | mataura
# Processing Record 10 of Set 3 | andilamena
# Processing Record 11 of Set 3 | saskylakh
# Processing Record 12 of Set 3 | porto novo
# Processing Record 13 of Set 3 | srednekolymsk
# Processing Record 14 of Set 3 | tabiauea
# City not found. Skipping...
# Processing Record 15 of Set 3 | vanimo
# Processing Record 16 of Set 3 | sept-iles
# Processing Record 17 of Set 3 | whitefish
# Processing Record 18 of Set 3 | taldan
# Processing Record 19 of Set 3 | nikolskoye
# Processing Record 20 of Set 3 | constitucion
# Processing Record 21 of Set 3 | ucluelet
# Processing Record 22 of Set 3 | arrecife
# Processing Record 23 of Set 3 | ndioum
# Processing Record 24 of Set 3 | sabinas hidalgo
# Processing Record 25 of Set 3 | kaeo
# Processing Record 26 of Set 3 | severo-kurilsk
# Processing Record 27 of Set 3 | calvia
# Processing Record 28 of Set 3 | arraial do cabo
# Processing Record 29 of Set 3 | kapaa
# Processing Record 30 of Set 3 | pioner
# Processing Record 31 of Set 3 | bereda
# Processing Record 32 of Set 3 | lagoa
# Processing Record 33 of Set 3 | kendari
# Processing Record 34 of Set 3 | saint george
# Processing Record 35 of Set 3 | anuradhapura
# Processing Record 36 of Set 3 | aksehir
# Processing Record 37 of Set 3 | bengkulu
# Processing Record 38 of Set 3 | bathsheba
# Processing Record 39 of Set 3 | derzhavinsk
# Processing Record 40 of Set 3 | tonkino
# Processing Record 41 of Set 3 | saldanha
# Processing Record 42 of Set 3 | coihaique
# Processing Record 43 of Set 3 | barcelos
# Processing Record 44 of Set 3 | chokurdakh
# Processing Record 45 of Set 3 | cidreira
# Processing Record 46 of Set 3 | saint-augustin
# Processing Record 47 of Set 3 | zvishavane
# Processing Record 48 of Set 3 | ribeira grande
# Processing Record 49 of Set 3 | vostok
# Processing Record 50 of Set 3 | xiaoweizhai
# Processing Record 1 of Set 4 | kodiak
# Processing Record 2 of Set 4 | maua
# Processing Record 3 of Set 4 | bretcu
# Processing Record 4 of Set 4 | san carlos
# Processing Record 5 of Set 4 | buqayq
# City not found. Skipping...
# Processing Record 6 of Set 4 | tumannyy
# City not found. Skipping...
# Processing Record 7 of Set 4 | san pedro carcha
# Processing Record 8 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 9 of Set 4 | khatanga
# Processing Record 10 of Set 4 | kaitangata
# Processing Record 11 of Set 4 | arlit
# Processing Record 12 of Set 4 | upernavik
# Processing Record 13 of Set 4 | somerset west
# Processing Record 14 of Set 4 | nome
# Processing Record 15 of Set 4 | baoro
# Processing Record 16 of Set 4 | skalistyy
# City not found. Skipping...
# Processing Record 17 of Set 4 | pyapon
# Processing Record 18 of Set 4 | kavieng
# Processing Record 19 of Set 4 | atuona
# Processing Record 20 of Set 4 | tasbuget
# City not found. Skipping...
# Processing Record 21 of Set 4 | zhigansk
# Processing Record 22 of Set 4 | grand centre
# City not found. Skipping...
# Processing Record 23 of Set 4 | kosonsoy
# Processing Record 24 of Set 4 | chuy
# Processing Record 25 of Set 4 | comodoro rivadavia
# Processing Record 26 of Set 4 | wulanhaote
# City not found. Skipping...
# Processing Record 27 of Set 4 | oistins
# Processing Record 28 of Set 4 | trairi
# Processing Record 29 of Set 4 | hobyo
# Processing Record 30 of Set 4 | sampit
# Processing Record 31 of Set 4 | batagay
# Processing Record 32 of Set 4 | kloulklubed
# Processing Record 33 of Set 4 | parana
# Processing Record 34 of Set 4 | iqaluit
# Processing Record 35 of Set 4 | yamada
# Processing Record 36 of Set 4 | rio gallegos
# Processing Record 37 of Set 4 | east london
# Processing Record 38 of Set 4 | edd
# Processing Record 39 of Set 4 | avarua
# Processing Record 40 of Set 4 | gisborne
# Processing Record 41 of Set 4 | richards bay
# Processing Record 42 of Set 4 | gat
# Processing Record 43 of Set 4 | wilmington
# Processing Record 44 of Set 4 | panaba
# Processing Record 45 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 46 of Set 4 | saint-gaudens
# Processing Record 47 of Set 4 | mount isa
# Processing Record 48 of Set 4 | guerrero negro
# Processing Record 49 of Set 4 | tezu
# Processing Record 50 of Set 4 | mergui
# City not found. Skipping...
# Processing Record 1 of Set 5 | vardo
# Processing Record 2 of Set 5 | samarai
# Processing Record 3 of Set 5 | oktyabrskiy
# Processing Record 4 of Set 5 | kenai
# Processing Record 5 of Set 5 | kualakapuas
# Processing Record 6 of Set 5 | black river
# Processing Record 7 of Set 5 | phan rang
# City not found. Skipping...
# Processing Record 8 of Set 5 | mayya
# Processing Record 9 of Set 5 | barcelona
# Processing Record 10 of Set 5 | iracoubo
# Processing Record 11 of Set 5 | the valley
# Processing Record 12 of Set 5 | asau
# Processing Record 13 of Set 5 | merritt island
# Processing Record 14 of Set 5 | mehamn
# Processing Record 15 of Set 5 | vila velha
# Processing Record 16 of Set 5 | san policarpo
# Processing Record 17 of Set 5 | thinadhoo
# Processing Record 18 of Set 5 | hailun
# Processing Record 19 of Set 5 | mar del plata
# Processing Record 20 of Set 5 | del rio
# Processing Record 21 of Set 5 | okhotsk
# Processing Record 22 of Set 5 | pringsewu
# Processing Record 23 of Set 5 | barentsburg
# City not found. Skipping...
# Processing Record 24 of Set 5 | alice springs
# Processing Record 25 of Set 5 | khandbari
# Processing Record 26 of Set 5 | cabo san lucas
# Processing Record 27 of Set 5 | marawi
# Processing Record 28 of Set 5 | seshcha
# Processing Record 29 of Set 5 | komsomolskiy
# Processing Record 30 of Set 5 | araure
# Processing Record 31 of Set 5 | vaitape
# Processing Record 32 of Set 5 | husavik
# Processing Record 33 of Set 5 | mugumu
# Processing Record 34 of Set 5 | alofi
# Processing Record 35 of Set 5 | taoudenni
# Processing Record 36 of Set 5 | san cristobal
# Processing Record 37 of Set 5 | cartagena
# Processing Record 38 of Set 5 | fort nelson
# Processing Record 39 of Set 5 | rafraf
# Processing Record 40 of Set 5 | nieuwpoort
# Processing Record 41 of Set 5 | maxixe
# Processing Record 42 of Set 5 | vao
# Processing Record 43 of Set 5 | berberati
# Processing Record 44 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 45 of Set 5 | det udom
# Processing Record 46 of Set 5 | puerto ayora
# Processing Record 47 of Set 5 | naryan-mar
# Processing Record 48 of Set 5 | cap-aux-meules
# Processing Record 49 of Set 5 | yakeshi
# Processing Record 50 of Set 5 | port elizabeth
# Processing Record 1 of Set 6 | sandovo
# Processing Record 2 of Set 6 | luganville
# Processing Record 3 of Set 6 | toliary
# City not found. Skipping...
# Processing Record 4 of Set 6 | hasaki
# Processing Record 5 of Set 6 | lorengau
# Processing Record 6 of Set 6 | heihe
# Processing Record 7 of Set 6 | japura
# Processing Record 8 of Set 6 | cap malheureux
# Processing Record 9 of Set 6 | bolungarvik
# City not found. Skipping...
# Processing Record 10 of Set 6 | samusu
# City not found. Skipping...
# Processing Record 11 of Set 6 | beringovskiy
# Processing Record 12 of Set 6 | liepaja
# Processing Record 13 of Set 6 | santa cruz
# Processing Record 14 of Set 6 | xining
# Processing Record 15 of Set 6 | bontang
# Processing Record 16 of Set 6 | dakar
# Processing Record 17 of Set 6 | sao filipe
# Processing Record 18 of Set 6 | kahului
# Processing Record 19 of Set 6 | odweyne
# Processing Record 20 of Set 6 | caravelas
# Processing Record 21 of Set 6 | camapua
# Processing Record 22 of Set 6 | juba
# Processing Record 23 of Set 6 | bethel
# Processing Record 24 of Set 6 | isangel
# Processing Record 25 of Set 6 | grindavik
# Processing Record 26 of Set 6 | conde
# Processing Record 27 of Set 6 | peto
# Processing Record 28 of Set 6 | praia
# Processing Record 29 of Set 6 | prata
# Processing Record 30 of Set 6 | borlange
# City not found. Skipping...
# Processing Record 31 of Set 6 | portland
# Processing Record 32 of Set 6 | berlevag
# Processing Record 33 of Set 6 | champasak
# Processing Record 34 of Set 6 | russell
# Processing Record 35 of Set 6 | belize
# Processing Record 36 of Set 6 | lebanon
# Processing Record 37 of Set 6 | taltal
# Processing Record 38 of Set 6 | maniitsoq
# Processing Record 39 of Set 6 | west wendover
# Processing Record 40 of Set 6 | bakchar
# Processing Record 41 of Set 6 | laguna
# Processing Record 42 of Set 6 | sinkat
# City not found. Skipping...
# Processing Record 43 of Set 6 | kununurra
# Processing Record 44 of Set 6 | wanning
# Processing Record 45 of Set 6 | aykhal
# Processing Record 46 of Set 6 | manadhoo
# Processing Record 47 of Set 6 | ahipara
# Processing Record 48 of Set 6 | carnarvon
# Processing Record 49 of Set 6 | eenhana
# Processing Record 50 of Set 6 | palora
# Processing Record 1 of Set 7 | tazovskiy
# Processing Record 2 of Set 7 | cururupu
# Processing Record 3 of Set 7 | semporna
# Processing Record 4 of Set 7 | lompoc
# Processing Record 5 of Set 7 | roma
# Processing Record 6 of Set 7 | balsas
# Processing Record 7 of Set 7 | esso
# Processing Record 8 of Set 7 | lydenburg
# Processing Record 9 of Set 7 | soe
# Processing Record 10 of Set 7 | katsina
# Processing Record 11 of Set 7 | port keats
# Processing Record 12 of Set 7 | meulaboh
# Processing Record 13 of Set 7 | wembley
# Processing Record 14 of Set 7 | adrar
# Processing Record 15 of Set 7 | rognan
# Processing Record 16 of Set 7 | sciacca
# Processing Record 17 of Set 7 | tunduru
# City not found. Skipping...
# Processing Record 18 of Set 7 | gimli
# Processing Record 19 of Set 7 | caibarien
# Processing Record 20 of Set 7 | high rock
# Processing Record 21 of Set 7 | yanan
# City not found. Skipping...
# Processing Record 22 of Set 7 | hovd
# Processing Record 23 of Set 7 | grajau
# Processing Record 24 of Set 7 | oyem
# Processing Record 25 of Set 7 | belmonte
# Processing Record 26 of Set 7 | carbonear
# Processing Record 27 of Set 7 | woodward
# Processing Record 28 of Set 7 | obregon
# Processing Record 29 of Set 7 | codrington
# Processing Record 30 of Set 7 | fortuna
# Processing Record 31 of Set 7 | deputatskiy
# Processing Record 32 of Set 7 | pilar
# Processing Record 33 of Set 7 | camacha
# Processing Record 34 of Set 7 | yar-sale
# Processing Record 35 of Set 7 | miri
# Processing Record 36 of Set 7 | bonthe
# Processing Record 37 of Set 7 | huilong
# Processing Record 38 of Set 7 | bogotol
# Processing Record 39 of Set 7 | torbay
# Processing Record 40 of Set 7 | neustadt
# Processing Record 41 of Set 7 | auki
# Processing Record 42 of Set 7 | arica
# Processing Record 43 of Set 7 | fare
# Processing Record 44 of Set 7 | kargasok
# Processing Record 45 of Set 7 | inderborskiy
# City not found. Skipping...
# Processing Record 46 of Set 7 | nambucca heads
# Processing Record 47 of Set 7 | acarau
# Processing Record 48 of Set 7 | ilulissat
# Processing Record 49 of Set 7 | radomsko
# Processing Record 50 of Set 7 | muswellbrook
# Processing Record 1 of Set 8 | shawnee
# Processing Record 2 of Set 8 | san ramon de la nueva oran
# Processing Record 3 of Set 8 | meyungs
# City not found. Skipping...
# Processing Record 4 of Set 8 | krasnoselkup
# Processing Record 5 of Set 8 | atar
# Processing Record 6 of Set 8 | dunedin
# Processing Record 7 of Set 8 | codajas
# Processing Record 8 of Set 8 | westport
# Processing Record 9 of Set 8 | beyneu
# Processing Record 10 of Set 8 | dawlatabad
# Processing Record 11 of Set 8 | nybro
# Processing Record 12 of Set 8 | esperance
# Processing Record 13 of Set 8 | victoria
# Processing Record 14 of Set 8 | san ignacio
# Processing Record 15 of Set 8 | nchelenge
# Processing Record 16 of Set 8 | chegdomyn
# Processing Record 17 of Set 8 | karratha
# Processing Record 18 of Set 8 | haines junction
# Processing Record 19 of Set 8 | statesboro
# Processing Record 20 of Set 8 | barybino
# Processing Record 21 of Set 8 | manoel urbano
# Processing Record 22 of Set 8 | corning
# Processing Record 23 of Set 8 | amapa
# Processing Record 24 of Set 8 | nemuro
# Processing Record 25 of Set 8 | fairbanks
# Processing Record 26 of Set 8 | cooma
# Processing Record 27 of Set 8 | half moon bay
# Processing Record 28 of Set 8 | seoul
# Processing Record 29 of Set 8 | maiduguri
# Processing Record 30 of Set 8 | mrirt
# City not found. Skipping...
# Processing Record 31 of Set 8 | aasiaat
# Processing Record 32 of Set 8 | abong mbang
# Processing Record 33 of Set 8 | kamariotissa
# Processing Record 34 of Set 8 | turukhansk
# Processing Record 35 of Set 8 | kikwit
# Processing Record 36 of Set 8 | onega
# Processing Record 37 of Set 8 | mayumba
# Processing Record 38 of Set 8 | ariquemes
# Processing Record 39 of Set 8 | mount gambier
# Processing Record 40 of Set 8 | mirabela
# Processing Record 41 of Set 8 | myanaung
# Processing Record 42 of Set 8 | herrin
# Processing Record 43 of Set 8 | grand forks
# Processing Record 44 of Set 8 | pemangkat
# Processing Record 45 of Set 8 | idritsa
# Processing Record 46 of Set 8 | arman
# Processing Record 47 of Set 8 | kainantu
# Processing Record 48 of Set 8 | hasanabad
# Processing Record 49 of Set 8 | kodinsk
# Processing Record 50 of Set 8 | dudinka
# Processing Record 1 of Set 9 | goderich
# Processing Record 2 of Set 9 | alekseyevsk
# Processing Record 3 of Set 9 | dafeng
# Processing Record 4 of Set 9 | poretskoye
# Processing Record 5 of Set 9 | buala
# Processing Record 6 of Set 9 | kuytun
# Processing Record 7 of Set 9 | suba
# Processing Record 8 of Set 9 | chagda
# City not found. Skipping...
# Processing Record 9 of Set 9 | shimorskoye
# Processing Record 10 of Set 9 | neiafu
# Processing Record 11 of Set 9 | chapais
# Processing Record 12 of Set 9 | satitoa
# City not found. Skipping...
# Processing Record 13 of Set 9 | kawana waters
# City not found. Skipping...
# Processing Record 14 of Set 9 | gao
# Processing Record 15 of Set 9 | korla
# Processing Record 16 of Set 9 | noshiro
# Processing Record 17 of Set 9 | tiksi
# Processing Record 18 of Set 9 | puerto leguizamo
# Processing Record 19 of Set 9 | arauca
# Processing Record 20 of Set 9 | waipawa
# Processing Record 21 of Set 9 | keokuk
# Processing Record 22 of Set 9 | bichura
# Processing Record 23 of Set 9 | aflu
# City not found. Skipping...
# Processing Record 24 of Set 9 | aviles
# Processing Record 25 of Set 9 | ghanzi
# Processing Record 26 of Set 9 | jiaozuo
# Processing Record 27 of Set 9 | warqla
# City not found. Skipping...
# Processing Record 28 of Set 9 | axim
# Processing Record 29 of Set 9 | manado
# Processing Record 30 of Set 9 | aitape
# Processing Record 31 of Set 9 | sangar
# Processing Record 32 of Set 9 | benguela
# Processing Record 33 of Set 9 | shemysheyka
# Processing Record 34 of Set 9 | spokane
# Processing Record 35 of Set 9 | shirokiy
# Processing Record 36 of Set 9 | baie-comeau
# Processing Record 37 of Set 9 | pacific grove
# Processing Record 38 of Set 9 | ulladulla
# Processing Record 39 of Set 9 | ardakan
# Processing Record 40 of Set 9 | tumaco
# Processing Record 41 of Set 9 | santa eulalia del rio
# City not found. Skipping...
# Processing Record 42 of Set 9 | sisimiut
# Processing Record 43 of Set 9 | debre birhan
# Processing Record 44 of Set 9 | aksarka
# Processing Record 45 of Set 9 | azimur
# City not found. Skipping...
# Processing Record 46 of Set 9 | holme
# Processing Record 47 of Set 9 | klaksvik
# Processing Record 48 of Set 9 | naustdal
# Processing Record 49 of Set 9 | saint-paul
# Processing Record 50 of Set 9 | basco
# Processing Record 1 of Set 10 | eslov
# Processing Record 2 of Set 10 | payson
# Processing Record 3 of Set 10 | cayenne
# Processing Record 4 of Set 10 | mussomeli
# Processing Record 5 of Set 10 | sao felix do xingu
# Processing Record 6 of Set 10 | miltenberg
# Processing Record 7 of Set 10 | kodinar
# Processing Record 8 of Set 10 | maragogi
# Processing Record 9 of Set 10 | jiayuguan
# Processing Record 10 of Set 10 | chumphon
# Processing Record 11 of Set 10 | lumeje
# Processing Record 12 of Set 10 | maceio
# Processing Record 13 of Set 10 | amahai
# Processing Record 14 of Set 10 | luino
# Processing Record 15 of Set 10 | bima
# Processing Record 16 of Set 10 | yuzawa
# Processing Record 17 of Set 10 | minab
# Processing Record 18 of Set 10 | grand-santi
# Processing Record 19 of Set 10 | zhangye
# Processing Record 20 of Set 10 | jejuri
# Processing Record 21 of Set 10 | san carlos del zulia
# Processing Record 22 of Set 10 | sarospatak
# Processing Record 23 of Set 10 | gongzhuling
# Processing Record 24 of Set 10 | francistown
# Processing Record 25 of Set 10 | katsiveli
# City not found. Skipping...
# Processing Record 26 of Set 10 | saint-denis
# Processing Record 27 of Set 10 | sakakah
# Processing Record 28 of Set 10 | labuan
# Processing Record 29 of Set 10 | mayo
# Processing Record 30 of Set 10 | kudahuvadhoo
# Processing Record 31 of Set 10 | kurchum
# Processing Record 32 of Set 10 | suzun
# Processing Record 33 of Set 10 | ilinskiy
# Processing Record 34 of Set 10 | jabiru
# City not found. Skipping...
# Processing Record 35 of Set 10 | hihifo
# City not found. Skipping...
# Processing Record 36 of Set 10 | yumen
# Processing Record 37 of Set 10 | teya
# Processing Record 38 of Set 10 | skibbereen
# Processing Record 39 of Set 10 | yunyang
# Processing Record 40 of Set 10 | jacareacanga
# Processing Record 41 of Set 10 | kjollefjord
# Processing Record 42 of Set 10 | cabedelo
# Processing Record 43 of Set 10 | guia de isora
# Processing Record 44 of Set 10 | galle
# Processing Record 45 of Set 10 | beitbridge
# Processing Record 46 of Set 10 | bertoua
# Processing Record 47 of Set 10 | tubmanburg
# Processing Record 48 of Set 10 | lar
# Processing Record 49 of Set 10 | pismo beach
# Processing Record 50 of Set 10 | tabukiniberu
# City not found. Skipping...
# Processing Record 1 of Set 11 | narsaq
# Processing Record 2 of Set 11 | rawannawi
# City not found. Skipping...
# Processing Record 3 of Set 11 | sitka
# Processing Record 4 of Set 11 | gweta
# Processing Record 5 of Set 11 | constantine
# Processing Record 6 of Set 11 | ilebo
# Processing Record 7 of Set 11 | kamenka
# Processing Record 8 of Set 11 | linxia
# Processing Record 9 of Set 11 | ostrovnoy
# Processing Record 10 of Set 11 | whitehorse
# Processing Record 11 of Set 11 | requena
# Processing Record 12 of Set 11 | ahvaz
# Processing Record 13 of Set 11 | inirida
# Processing Record 14 of Set 11 | karaul
# City not found. Skipping...
# Processing Record 15 of Set 11 | nelson bay
# Processing Record 16 of Set 11 | sabha
# Processing Record 17 of Set 11 | bacolod
# Processing Record 18 of Set 11 | magadi
# Processing Record 19 of Set 11 | ayia galini
# Processing Record 20 of Set 11 | hastings
# Processing Record 21 of Set 11 | halalo
# City not found. Skipping...
# Processing Record 22 of Set 11 | sao joao da barra
# Processing Record 23 of Set 11 | zhezkazgan
# Processing Record 24 of Set 11 | saint-leu
# Processing Record 25 of Set 11 | khonuu
# City not found. Skipping...
# Processing Record 26 of Set 11 | aksu
# Processing Record 27 of Set 11 | douglas
# Processing Record 28 of Set 11 | ginda
# Processing Record 29 of Set 11 | kurikka
# Processing Record 30 of Set 11 | kharp
# Processing Record 31 of Set 11 | lakes entrance
# Processing Record 32 of Set 11 | grand river south east
# City not found. Skipping...
# Processing Record 33 of Set 11 | shubarkuduk
# Processing Record 34 of Set 11 | olafsvik
# Processing Record 35 of Set 11 | massaguet
# Processing Record 36 of Set 11 | malanville
# Processing Record 37 of Set 11 | eyl
# Processing Record 38 of Set 11 | marcona
# City not found. Skipping...
# Processing Record 39 of Set 11 | viligili
# City not found. Skipping...
# Processing Record 40 of Set 11 | wakkanai
# Processing Record 41 of Set 11 | quesnel
# Processing Record 42 of Set 11 | marsh harbour
# Processing Record 43 of Set 11 | avera
# Processing Record 44 of Set 11 | vylgort
# City not found. Skipping...
# Processing Record 45 of Set 11 | hanzhong
# Processing Record 46 of Set 11 | henderson
# Processing Record 47 of Set 11 | mangai
# Processing Record 48 of Set 11 | wajima
# Processing Record 49 of Set 11 | baherden
# Processing Record 50 of Set 11 | imeni zhelyabova
# Processing Record 1 of Set 12 | balikpapan
# Processing Record 2 of Set 12 | mahibadhoo
# Processing Record 3 of Set 12 | port hedland
# Processing Record 4 of Set 12 | bida
# Processing Record 5 of Set 12 | santa maria
# Processing Record 6 of Set 12 | leningradskiy
# Processing Record 7 of Set 12 | santa cruz de tenerife
# Processing Record 8 of Set 12 | marica
# Processing Record 9 of Set 12 | livramento
# Processing Record 10 of Set 12 | general pico
# Processing Record 11 of Set 12 | mitsamiouli
# Processing Record 12 of Set 12 | talara
# Processing Record 13 of Set 12 | shingu
# Processing Record 14 of Set 12 | general roca
# Processing Record 15 of Set 12 | dibulla
# Processing Record 16 of Set 12 | calvinia
# Processing Record 17 of Set 12 | rameshki
# Processing Record 18 of Set 12 | baijiantan
# Processing Record 19 of Set 12 | acapulco
# Processing Record 20 of Set 12 | puerto maldonado
# Processing Record 21 of Set 12 | jalu
# Processing Record 22 of Set 12 | talnakh
# Processing Record 23 of Set 12 | nantucket
# Processing Record 24 of Set 12 | nishihara
# Processing Record 25 of Set 12 | tonj
# Processing Record 26 of Set 12 | griffith
# Processing Record 27 of Set 12 | hayden
# Processing Record 28 of Set 12 | saint-hyacinthe
# Processing Record 29 of Set 12 | fort saint john
# City not found. Skipping...
# Processing Record 30 of Set 12 | ratnagiri
# Processing Record 31 of Set 12 | santo antonio da platina
# Processing Record 32 of Set 12 | micheweni
# Processing Record 33 of Set 12 | pisco
# Processing Record 34 of Set 12 | san patricio
# Processing Record 35 of Set 12 | salta
# Processing Record 36 of Set 12 | barysh
# Processing Record 37 of Set 12 | yarkovo
# Processing Record 38 of Set 12 | palghar
# Processing Record 39 of Set 12 | labuhan
# Processing Record 40 of Set 12 | langsa
# Processing Record 41 of Set 12 | luderitz
# Processing Record 42 of Set 12 | gizo
# Processing Record 43 of Set 12 | touros
# Processing Record 44 of Set 12 | athabasca
# Processing Record 45 of Set 12 | asasa
# Processing Record 46 of Set 12 | port-gentil
# Processing Record 47 of Set 12 | nadym
# Processing Record 48 of Set 12 | lodja
# Processing Record 49 of Set 12 | bairiki
# Processing Record 50 of Set 12 | sedelnikovo
# City not found. Skipping...
# Processing Record 1 of Set 13 | celestun
# Processing Record 2 of Set 13 | necochea
# Processing Record 3 of Set 13 | shimoda
# Processing Record 4 of Set 13 | panorama
# Processing Record 5 of Set 13 | wladyslawowo
# Processing Record 6 of Set 13 | coihueco
# Processing Record 7 of Set 13 | brae
# Processing Record 8 of Set 13 | nongstoin
# Processing Record 9 of Set 13 | yulara
# Processing Record 10 of Set 13 | zhangjiakou
# Processing Record 11 of Set 13 | mangalia
# Processing Record 12 of Set 13 | cockburn town
# Processing Record 13 of Set 13 | yarim
# Processing Record 14 of Set 13 | port hardy
# Processing Record 15 of Set 13 | umzimvubu
# City not found. Skipping...
# Processing Record 16 of Set 13 | jumla
# Processing Record 17 of Set 13 | bure
# Processing Record 18 of Set 13 | aksha
# Processing Record 19 of Set 13 | tomatlan
# Processing Record 20 of Set 13 | ostersund
# Processing Record 21 of Set 13 | yerbogachen
# Processing Record 22 of Set 13 | pekalongan
# Processing Record 23 of Set 13 | ponta delgada
# Processing Record 24 of Set 13 | khani
# Processing Record 25 of Set 13 | tornio
# Processing Record 26 of Set 13 | ajdabiya
# Processing Record 27 of Set 13 | kinsale
# Processing Record 28 of Set 13 | omboue
# Processing Record 29 of Set 13 | duz
# City not found. Skipping...
# Processing Record 30 of Set 13 | road town
# Processing Record 31 of Set 13 | kashi
# Processing Record 32 of Set 13 | ancud
# Processing Record 33 of Set 13 | lexington
# Processing Record 34 of Set 13 | pecos
# Processing Record 35 of Set 13 | ukmerge
# Processing Record 36 of Set 13 | jurilovca
# Processing Record 37 of Set 13 | kaura namoda
# Processing Record 38 of Set 13 | kazalinsk
# City not found. Skipping...
# Processing Record 39 of Set 13 | carlsbad
# Processing Record 40 of Set 13 | coquimbo
# Processing Record 41 of Set 13 | bogense
# Processing Record 42 of Set 13 | caborca
# Processing Record 43 of Set 13 | petropavlovsk-kamchatskiy
# Processing Record 44 of Set 13 | cognac
# Processing Record 45 of Set 13 | caluquembe
# Processing Record 46 of Set 13 | terra santa
# Processing Record 47 of Set 13 | scottsburgh
# City not found. Skipping...
# Processing Record 48 of Set 13 | nguiu
# City not found. Skipping...
# Processing Record 49 of Set 13 | bayir
# Processing Record 50 of Set 13 | orocue
# Processing Record 1 of Set 14 | bay roberts
# Processing Record 2 of Set 14 | isla mujeres
# Processing Record 3 of Set 14 | sri aman
# Processing Record 4 of Set 14 | armacao dos buzios
# City not found. Skipping...
# Processing Record 5 of Set 14 | abnub
# Processing Record 6 of Set 14 | lagunas
# Processing Record 7 of Set 14 | north bend
# Processing Record 8 of Set 14 | manggar
# Processing Record 9 of Set 14 | clyde river
# Processing Record 10 of Set 14 | kazuno
# Processing Record 11 of Set 14 | igrim
# Processing Record 12 of Set 14 | muros
# Processing Record 13 of Set 14 | altay
# Processing Record 14 of Set 14 | yola
# Processing Record 15 of Set 14 | iralaya
# Processing Record 16 of Set 14 | shieli
# Processing Record 17 of Set 14 | bambanglipuro
# Processing Record 18 of Set 14 | jeremie
# Processing Record 19 of Set 14 | kalininsk
# Processing Record 20 of Set 14 | shasta lake
# Processing Record 21 of Set 14 | bemidji
# Processing Record 22 of Set 14 | zavitinsk
# Processing Record 23 of Set 14 | maamba
# Processing Record 24 of Set 14 | qiongshan
# Processing Record 25 of Set 14 | antofagasta
# Processing Record 26 of Set 14 | rio do sul
# Processing Record 27 of Set 14 | lima
# Processing Record 28 of Set 14 | sosua
# Processing Record 29 of Set 14 | craigieburn
# Processing Record 30 of Set 14 | djougou
# Processing Record 31 of Set 14 | kropotkin
# Processing Record 32 of Set 14 | dabola
# Processing Record 33 of Set 14 | sao desiderio
# Processing Record 34 of Set 14 | shakiso
# Processing Record 35 of Set 14 | keshan
# City not found. Skipping...
# Processing Record 36 of Set 14 | creel
# Processing Record 37 of Set 14 | souillac
# Processing Record 38 of Set 14 | cefalu
# Processing Record 39 of Set 14 | yeppoon
# Processing Record 40 of Set 14 | harper
# Processing Record 41 of Set 14 | paidha
# Processing Record 42 of Set 14 | henties bay
# Processing Record 43 of Set 14 | jutai
# Processing Record 44 of Set 14 | naze
# Processing Record 45 of Set 14 | mabaruma
# Processing Record 46 of Set 14 | porto velho
# Processing Record 47 of Set 14 | choma
# Processing Record 48 of Set 14 | bilma
# Processing Record 49 of Set 14 | superior
# Processing Record 50 of Set 14 | niono
# Processing Record 1 of Set 15 | sao raimundo nonato
# Processing Record 2 of Set 15 | lensk
# Processing Record 3 of Set 15 | gornopravdinsk
# Processing Record 4 of Set 15 | havre-saint-pierre
# Processing Record 5 of Set 15 | kytlym
# City not found. Skipping...
# Processing Record 6 of Set 15 | dabat
# Processing Record 7 of Set 15 | qaqortoq
# Processing Record 8 of Set 15 | bulgan
# Processing Record 9 of Set 15 | boguchany
# Processing Record 10 of Set 15 | wuzhou
# Processing Record 11 of Set 15 | kurilsk
# Processing Record 12 of Set 15 | popondetta
# Processing Record 13 of Set 15 | novyy urengoy
# Processing Record 14 of Set 15 | ericeira
# Processing Record 15 of Set 15 | puerto narino
# Processing Record 16 of Set 15 | ibb
# Processing Record 17 of Set 15 | svarstad
# Processing Record 18 of Set 15 | alpena
# Processing Record 19 of Set 15 | kichera
# Processing Record 20 of Set 15 | lucea
# Processing Record 21 of Set 15 | summerville
# Processing Record 22 of Set 15 | hambantota
# Processing Record 23 of Set 15 | bonga
# Processing Record 24 of Set 15 | saint-louis
# Processing Record 25 of Set 15 | batticaloa
# Processing Record 26 of Set 15 | pitimbu
# Processing Record 27 of Set 15 | catamarca
# Processing Record 28 of Set 15 | chukhloma
# Processing Record 29 of Set 15 | trelew
# Processing Record 30 of Set 15 | severo-yeniseyskiy
# Processing Record 31 of Set 15 | bardiyah
# Processing Record 32 of Set 15 | vanavara
# Processing Record 33 of Set 15 | fevralsk
# City not found. Skipping...
# Processing Record 34 of Set 15 | gazimurskiy zavod
# Processing Record 35 of Set 15 | takoradi
# Processing Record 36 of Set 15 | riverton
# Processing Record 37 of Set 15 | rocha
# Processing Record 38 of Set 15 | vuktyl
# Processing Record 39 of Set 15 | east moline
# Processing Record 40 of Set 15 | kings mountain
# Processing Record 41 of Set 15 | saint anthony
# Processing Record 42 of Set 15 | margate
# Processing Record 43 of Set 15 | bourail
# Processing Record 44 of Set 15 | palabuhanratu
# City not found. Skipping...
# Processing Record 45 of Set 15 | caninde
# Processing Record 46 of Set 15 | orange cove
# Processing Record 47 of Set 15 | pangnirtung
# Processing Record 48 of Set 15 | sioux lookout
# Processing Record 49 of Set 15 | tehri
# Processing Record 50 of Set 15 | yilan
# Processing Record 1 of Set 16 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 2 of Set 16 | beloha
# Processing Record 3 of Set 16 | lolua
# City not found. Skipping...
# Processing Record 4 of Set 16 | varnavino
# Processing Record 5 of Set 16 | bargal
# City not found. Skipping...
# Processing Record 6 of Set 16 | nouadhibou
# Processing Record 7 of Set 16 | algodones
# Processing Record 8 of Set 16 | monrovia
# Processing Record 9 of Set 16 | stjordalshalsen
# Processing Record 10 of Set 16 | hofn
# Processing Record 11 of Set 16 | asfi
# Processing Record 12 of Set 16 | tabulbah
# City not found. Skipping...
# Processing Record 13 of Set 16 | la ronge
# Processing Record 14 of Set 16 | vila do maio
# Processing Record 15 of Set 16 | aberdeen
# Processing Record 16 of Set 16 | zhicheng
# Processing Record 17 of Set 16 | maghama
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 695

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0           Albany  42.6001  -73.9662     43.00        71         100
# 1            Bluff -46.6000  168.3333     55.99        78         100
# 2          Kuusamo  65.9667   29.1833     32.00        86          90
# 3         Tasiilaq  65.6145  -37.6368     26.60        50          96
# 4  Bambous Virieux -20.3428   57.7575     84.00        89          75
# 5          Aklavik  68.2191 -135.0107     -2.20        77         100
# 6            Airai  -8.9266  125.4092     63.93        92         100
# 7           Rawson -43.3002  -65.1023     59.16        87         100
# 8        Mahebourg -20.4081   57.7000     78.80        89          75
# 9            Beira -19.8436   34.8389     72.95        78          19
#
#    Wind Speed Country Current Description
# 0        3.00      US       moderate rain
# 1        1.99      NZ     overcast clouds
# 2       12.66      FI          light snow
# 3        4.61      GL     overcast clouds
# 4        3.44      MU       broken clouds
# 5        8.05      CA          light snow
# 6        1.61      TL     overcast clouds
# 7        7.20      AR     overcast clouds
# 8        3.44      MU       broken clouds
# 9        4.18      MZ          few clouds

# %%
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df
# Out:
#                 City Country      Lat       Lng  Max Temp  Humidity  \
# 0             Albany      US  42.6001  -73.9662     43.00        71
# 1              Bluff      NZ -46.6000  168.3333     55.99        78
# 2            Kuusamo      FI  65.9667   29.1833     32.00        86
# 3           Tasiilaq      GL  65.6145  -37.6368     26.60        50
# 4    Bambous Virieux      MU -20.3428   57.7575     84.00        89
# ..               ...     ...      ...       ...       ...       ...
# 690             Asfi      MA  32.2994   -9.2372     60.55        87
# 691         La Ronge      CA  55.1001 -105.2842     35.60        75
# 692     Vila Do Maio      CV  15.1333  -23.2167     68.00        77
# 693         Aberdeen      GB  57.1437   -2.0981     37.40        81
# 694         Zhicheng      CN  30.2956  111.5047     54.00        95
#
#      Cloudiness  Wind Speed Current Description
# 0           100        3.00       moderate rain
# 1           100        1.99     overcast clouds
# 2            90       12.66          light snow
# 3            96        4.61     overcast clouds
# 4            75        3.44       broken clouds
# ..          ...         ...                 ...
# 690           0        9.37           clear sky
# 691          90        4.61     overcast clouds
# 692          75       14.97       broken clouds
# 693          90        5.75     overcast clouds
# 694         100        3.27       moderate rain
#
# [695 rows x 9 columns]

# %%
# Create the output file (CSV).

output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
